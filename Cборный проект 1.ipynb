# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Ата :)
#
# Спасибо за работу на проекте и за все исправления
#
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# добавил пару подсказок и бонус
# <br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Ата :) Спасибо, что прислал задание 🤝 Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# __Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие, а ты попробуешь исправить ее самостоятельно. Но если ты пока не справишься с такой задачей — при следующей проверке я дам более подробную подсказку!__
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://devpractice.ru/matplotlib-book/">“Библиотека Matplotlib” доступна для скачивания БЕСПЛАТНО!</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...

# %% [markdown]
# ## Исследование данных о российском кинопрокате

# %% [markdown]
# - Описание проекта
#
#
# Заказчик этого исследования — Министерство культуры Российской Федерации.
# Нужно изучить рынок российского кинопроката и выявить текущие тренды. Уделить внимание фильмам, которые получили государственную поддержку. Ответить на вопрос, насколько такие фильмы интересны зрителю.
# Будем работать с данными, опубликованными на портале открытых данных Министерства культуры. Набор данных содержит информацию о прокатных удостоверениях, сборах и государственной поддержке фильмов, а также информацию с сайта КиноПоиск.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит добавить подробностей, без которых тяжело будет вспомнить через полгода суть проекта (без отдельного брифа проекта)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит добавлять еще больше подробностей к плану, это позволит избежать многих ошибок на будущих проектах

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import pyplot

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />   Кажется, в этот раз весь код на проекте запускался вручную ... 641-я строка кода в начале проекта
#
# ![image-3.png](attachment:image-3.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
#
#
# Проверить работоспособность кода — можно нажав на панели Jupiter Hub Kernel и Restart & Run All (см скриншот ниже).
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Шаг 1. Откройте файлы с данными и объедините их в один датафрейм.
#
# Объедините данные таким образом, чтобы все объекты из датасета `mkrf_movies` обязательно вошли в получившийся датафрейм.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_0" aria-expanded="false" aria-controls="collapseHint_0">Подсказка</button>
#         </div>
#         <div id="collapseHint_0" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на тип данных столбца, по которому будете соединять датафреймы. Тип данных этих столбцов должен быть одинаковым в обоих датафреймах.
#             </div>
#         </div>
#     </div>
# </div>

# %%
# Посмотрим на начальные данные из mkrf_movies.csv
mkrf_movies = pd.read_csv('/datasets/mkrf_movies.csv')
display(mkrf_movies.head(10))
mkrf_movies.info()
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
# 4          Особо опасен  221030815  2015-07-29T12:00:00.000Z  Художественный
# 5     Остановился поезд  111013816  2016-09-13T12:00:00.000Z  Художественный
# 6       Любовь и голуби  111007013  2013-10-18T12:00:00.000Z  Художественный
# 7     Любовь и сигареты  221074614  2014-12-29T12:00:00.000Z  Художественный
# 8    Отпетые мошенники.  121011416  2016-05-05T12:00:00.000Z  Художественный
# 9   Отпуск за свой счет  111019114  2014-12-01T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# ...

# %%
mkrf_shows = pd.read_csv('/datasets/mkrf_shows.csv')
def all_f():
    display(mkrf_shows.head(10))
    mkrf_shows.info()
all_f()
# Out:
#     puNumber    box_office
# 0  111000113  2.450000e+03
# 1  111000115  6.104000e+04
# 2  111000116  1.530300e+08
# 3  111000117  1.226096e+07
# 4  111000118  1.636841e+08
# 5  111000119  4.293650e+06
# 6  111000212  2.000000e+02
# 7  111000216  3.555670e+05
# 8  111000313  7.100000e+02
# 9  111000314  1.607970e+06
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3158 entries, 0 to 3157
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   puNumber    3158 non-null   int64
#  1   box_office  3158 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 49.5 KB

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Все  методы можно собрать в функцию и оптимизировать код вывода первичной информации
#
#         def ...:
#             ... dataset.head()
#             ... dataset.info()

# %% [markdown]
# <div style>
# <font size="4"><b></b></font>
# <font size="5", color = "black">
# 🤝

# %%
mkrf_movies.puNumber.value_counts()
# Out:
# 221054410    2
# 221154310    2
# 111028314    1
# 121010616    1
# 121000819    1
#             ..
# 111019014    1
# 121032119    1
# 221138610    1
# 121016011    1
# 121020013    1
# Name: puNumber, Length: 7484, dtype: int64

# %%
# Заменим значение "Нет" столбца puNumber и переведём его в int64
mkrf_movies.loc[mkrf_movies['puNumber'] == 'нет', 'puNumber'] = 0
mkrf_movies['puNumber'] = pd.to_numeric(mkrf_movies['puNumber'])
mkrf_movies.dtypes
# Out:
# title                     object
# puNumber                   int64
# show_start_date           object
# type                      object
# film_studio               object
# production_country        object
# director                  object
# producer                  object
# age_restriction           object
# refundable_support       float64
# nonrefundable_support    float64
# budget                   float64
# financing_source          object
# ratings                   object
# genres                    object
# dtype: object

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />В реальной работе, перед объединением стоит более подробно изучить данные, например на наличие полных дубликатов

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Стоит применять «змеиный стиль» в названиях переменных и колонках
#
#         ['puNumber']
#
#         ['pu_number']
#
# [Для чего придуман PEP8](https://letpy.com/python-guide/pep8/?ysclid=lkvf7o0xjl57413288)

# %%
data = mkrf_movies.merge(mkrf_shows, on='puNumber', how='left')
display(data.head(10))
data.info()
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
# 4          Особо опасен  221030815  2015-07-29T12:00:00.000Z  Художественный
# 5     Остановился поезд  111013816  2016-09-13T12:00:00.000Z  Художественный
# 6       Любовь и голуби  111007013  2013-10-18T12:00:00.000Z  Художественный
# 7     Любовь и сигареты  221074614  2014-12-29T12:00:00.000Z  Художественный
# 8    Отпетые мошенники.  121011416  2016-05-05T12:00:00.000Z  Художественный
# 9   Отпуск за свой счет  111019114  2014-12-01T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# ...

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> По умолчанию этот метод выводит 5 строк, 5-ку можно не писать
#
#             .head(5)

# %% [markdown]
# При совмещении двух столбцов были обнаружены следующие ошибки: изначально тип данных был object, пришлось переводить в int64, а также в одной из строк вместо индивидуального id стояло 'Нет', что приписывало столбцу тип данных object. Это говорило нам об отсутствии лицензии, мы заменили её на 0.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит обратить внимание на параметры, которые пандас выставляет по умолчанию при merge (для справки в join такая же «засада» по характеру, но другая по исполнению)
#
# Использование параметров по умолчанию может привести к потере данных при объединении
#
#
# [Примеры объединения таблиц, merge](https://pandas.pydata.org/pandas-docs/version/1.5/reference/api/pandas.DataFrame.merge.html?highlight=merge#pandas.DataFrame.merge)
#
# [Примеры объединения таблиц, join](https://pandas.pydata.org/pandas-docs/version/1.5/reference/api/pandas.DataFrame.join.html?highlight=join#pandas.DataFrame.join)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Можно добавить минивывод о результатах объединения, сохранилась ли размерность таблиц (по денежным колонкам особенно), не появились ли лишние пропуски
#
# Заказчику эта таблица ничего не расскажет, т.к. он не исследовал эти данные, он не знает, что и с чем сравнивать

# %% [markdown]
# Нужно исправить:
#
# В типе фильма есть одинаковые значения, но в некоторых допущен лишний пробел впереди названия;
# В значениях столбца puNumber есть лишние пробелы;
# Есть пропуски:
#
# В film_studio. Всего 18 пропусков;
# Пропуски в production_country.
# Пропуски в director. Всего 9 пропусков;
# В producer - 568 пропусков;
# Пропущена значительная часть данный в refundable_support, nonrefundable_support, budget, financing_source. Но в описании указано, что эти данные указаны только для тех фильмов, которые получили государственную поддержку. Также бюджет этих фильмов указан с учетом государственной поддержки;
# Пропуски в genres и ratings
# В датасете mkrf_movies в основном столбцы с категориальными переменными, из количественных только refundable_support, nonrefundable_support, budget.
#
# mkrf_shows не содержит пропусков, номера лицензий не повторяются. Интересно, что есть и сборы, равные нулю. Получается какие-то картины так и не вышли в прокат, либо на них никто не ходил. Еще нулевые сборы могут означать, что эти картины были выполнены по заказу, поэтому в прокат не выходили. Вариантов много.
#
# Чтобы объединить эти датасеты нам необходимо исправить значения в столбце puNumber

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %%
data.hist(figsize=(15, 15))
None

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит добавить вывод для  каждого графика на проекте

# %% [markdown]
# #### Шаг 2.1. Проверьте типы данных
#
# - Проверьте типы данных в датафрейме и преобразуйте их там, где это необходимо.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   int64
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
# ...

# %%
data.type.value_counts()
# Out:
# Художественный                4520
#  Художественный               1389
# Анимационный                   828
# Прочие                         406
# Документальный                 288
# Научно-популярный               53
#  Анимационный                    1
# Музыкально-развлекательный       1
# Name: type, dtype: int64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Скажи пожалуйста, что ты делаешь с этим кодом в этом разделе проекта?
#
#         1.2.1  Шаг 2.1. Проверьте типы данных
#         data.type.value_counts()

# %% [markdown]
# Просто решил посмотреть значения всех столбцов для возможной предобработки

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Этот код показывает тебе значения только одной колонки
#
#         data.type
#
# ['type']
#
# К проверке типов данных этот код не имеет отношения 🤝
#
#         2.1. Проверьте типы данных

# %%
columns = data.select_dtypes(include='object').columns
columns
# Out:
# Index(['title', 'show_start_date', 'type', 'film_studio', 'production_country',
#        'director', 'producer', 'age_restriction', 'financing_source',
#        'ratings', 'genres'],
#       dtype='object')

# %%
data.production_country.value_counts()
# Out:
# США                               2172
# Россия                            1821
# СССР                               347
# Франция                            301
# Великобритания                     257
#                                   ...
# США-Венгрия                          1
# Франция-Испания-Бельгия-Панама       1
# США - ЮАР - Гонконг                  1
# Нидерланды, Бельгия                  1
# США - Индия - ОАЭ                    1
# Name: production_country, Length: 950, dtype: int64

# %% [markdown]
# #### Шаг 2.2. Изучите пропуски в датафрейме
#
# - Объясните, почему заполнили пропуски определённым образом или почему не стали этого делать.

# %%
# check
# пропущенные значения бары

def pass_value_barh(dfg):
    try:
        (
            (dfg.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) или произошла ошибка в первой части функции ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста
#
# __мой график оформлен не совсем корректно, сможешь отметить, что стоило бы исправить в графике?__

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Код можно удалять по частям и узнавать за что отвечает та или иная строка 🤝
#
#
#             (df.isna().mean()*100) — расчет пропусков
#             .to_frame() — превращение серии в датафрейм
#             .rename(columns = {0:'space'}) — переименование полученного столбца, чтобы можно было обращаться по имени
#             .query('space > 0') — фильтрация полученных строк, чтобы не выводить строки, где данные без пропусков
#             .sort_values(by = 'space', ascending = True) — сортировка
#             .plot(kind= 'barh', figsize=(19,6), rot = -5, legend = False, fontsize = 16) — отрисовка графика
#             .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')  — установка названия

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Цвет у шрифта заголовка почти совпадает с цветом у баров
#
# За поворот текста на оси `Y` отвечает параметр `rot`, стоит обнулить
#
# Можно добавить обозначение оси `Х` (процент записей с пропусками)
#
#         df.isna().mean()*100 — для расчета процента пропусков в колонке
#
# На графике мы оцениваем масштаб проблемы с пропусками и возможное совпадение % пропущенных значений в колонках
#
# добавить подписи к осям мешает строка кода
#
#         .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')
#
# её можно заменить на
#
#         ;
#         plt.title('Пропущенные значения, %' + "\n", fontsize=22, color='SteelBlue')
#         plt.xlabel('Процент пропусков', fontsize=22)
#         plt.ylabel('Столбцы с пропусками')
#
# плюс можно установить шкалу от 0 до 100, чтобы визуально представлять долю пропусков
#
#         plt.xlim(0, 100)
#
# часть моих новых шрифтов оформлена не совсем корректно 🤝😉

# %%
data.financing_source = data.financing_source.fillna('unknown')
data.genres = data.genres.fillna('unknown')
data.producer = data.producer.fillna('unknown')
data.film_studio = data.film_studio.fillna('unknown')
data.director = data.director.fillna('unknown')
data.production_country = data.production_country.fillna('unknown')

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Верное решение для категориальных данных, молодец

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />цикл for остался без работы
#
#         data.financing_source = data.financing_source.fillna('unknown')
#         data.genres = data.genres.fillna('unknown')
#         data.producer = data.producer.fillna('unknown')
#         data.film_studio = data.film_studio.fillna('unknown')
#         data.director = data.director.fillna('unknown')
#         data.production_country = data.production_country.fillna('unknown')
#
# можно объединить код

# %% [markdown]
# Здесь все довольно просто, заполнил пропуски в столбцах с категориальным признаком.

# %%
def get_first_value(s, sep = ','):
    value_lst = s.split(sep = sep)
    return value_lst[0]
data['age_restriction'] = data['age_restriction'].apply(lambda x: get_first_value(x, sep = '-'))

# %%
data[:].isna().sum()
# Out:
# title                       0
# puNumber                    0
# show_start_date             0
# type                        0
# film_studio                 0
# production_country          0
# director                    0
# producer                    0
# age_restriction             0
# refundable_support       7154
# nonrefundable_support    7154
# budget                   7154
# financing_source            0
# ratings                   967
# genres                      0
# box_office               4328
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7486 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   int64
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7486 non-null   object
#  5   production_country     7486 non-null   object
#  6   director               7486 non-null   object
#  7   producer               7486 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       7486 non-null   object
#  13  ratings                6519 non-null   object
# ...

# %%
data['show_start_date'] = pd.to_datetime(data['show_start_date'], format='%Y-%m-%dT%H:%M:%S', errors='coerce')

# %%
data['show_start_date'] = data['show_start_date'].dt.date

# %%
# check
data['show_start_date'][:2]
# Out:
# 0    2015-11-27
# 1    2016-09-13
# Name: show_start_date, dtype: object

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Во время форматирования стоит избавиться от части информации, если она не несет пользу
#
#         12:00:00+00:00

# %% [markdown]
# Исправил столбец с датами

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, избавились  от части информации
#
#
#         12:00:00+00:00
#
# После
#
#         .dt.date
#
# у нас колонка поменяла тип на
#
#         2   show_start_date        7484 non-null   object
#         dtype: object
#
# Другой метод позволит избежать изменения типа данных
#
#         .astype('datetime64[D]')

# %%
data[:].isna().sum()
# Out:
# title                       0
# puNumber                    0
# show_start_date             0
# type                        0
# film_studio                 0
# production_country          0
# director                    0
# producer                    0
# age_restriction             0
# refundable_support       7154
# nonrefundable_support    7154
# budget                   7154
# financing_source            0
# ratings                   967
# genres                      0
# box_office               4328
# dtype: int64

# %%
print('% NaN in ratings =', round(_.shape[0] / data.shape[0] * 100, 2))
# Out:
# % NaN in ratings = 0.21

# %%
# check
data.shape
# Out:
# (7486, 16)

# %%
#data = data.loc[data.ratings.isna() == False]

# %% [markdown]
# Удалим строки NaN в столбце с рейтингом

# %%
# check
data.shape
# Out:
# (7486, 16)

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Скажи пожалуйста, по какой причине мы удаляем такое кол-во строк
#
#         data = data.loc[data.ratings.isna() == False]
#
# и в чем ценность такого решения?
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)

# %%
data.ratings.value_counts()
# Out:
# 6.6    312
# 6.7    308
# 6.8    261
# 7.2    252
# 6.2    243
#       ...
# 1.8      1
# 64%      1
# 1.9      1
# 9.2      1
# 1.0      1
# Name: ratings, Length: 94, dtype: int64

# %%
cond: bool = (data.ratings.str.find('%') != -1) & (data.ratings.isna() == False)
print('строки с % =', data.loc[cond, 'ratings'].shape[0])
print('% =', round(data.loc[cond, 'ratings'].shape[0] / data.shape[0] * 100, 2))
# Out:
# строки с % = 29
# % = 0.39

# %%
data.loc[cond, 'ratings'] = data.loc[cond, 'ratings'].str.slice(0, -1).astype('uint8') / 10

data.ratings.value_counts()
# Out:
# 6.6    312
# 6.7    308
# 6.8    261
# 7.2    252
# 6.2    243
#       ...
# 1.9      1
# 9.2      1
# 2.8      1
# 6.2      1
# 1.9      1
# Name: ratings, Length: 94, dtype: int64

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> У нас нет уверенности в том, что мы получим истинную оценку, откинув процент. Можно удалить значения в этой колонке, если их немного

# %% [markdown]
# #### Шаг 2.3. Изучите дубликаты в датафрейме
# - Проверьте, есть ли в данных дубликаты. Опишите причины, которые могли повлиять на появление дублей.

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data[data['title'].duplicated(keep=False)]
# Out:
#                                                   title   puNumber  \
# 2                                          Особо опасен  221038416
# 3                                          Особо опасен  221026916
# 4                                          Особо опасен  221030815
# 12    Малышка на миллион /По мотивам рассказов Ф.Х.Т...  221011415
# 26                                      Оружейный барон  221012515
# ...                                                 ...        ...
# 7369                                          Невиновен  111019319
# 7416                             Отель "Гранд Будапешт"  121035119
# 7438                                              Зверь  121035919
# 7450                                      В тихом омуте  121036919
# 7474                                          Вторжение  111022519
#
#      show_start_date             type  \
# 2         2016-10-10   Художественный
# 3         2016-06-10   Художественный
# 4         2015-07-29   Художественный
# ...

# %%
data[(data['title'].duplicated(keep=False)) & (data['box_office'].isna() == False)]
# Out:
#                                                   title   puNumber  \
# 110   Гарри Поттер и орден Феникса /По роману Дж.К.Р...  121026316
# 111   Гарри Поттер и тайная комната /По роману Дж.К....  121026016
# 113   Гарри Поттер и узник Азкабана /По роману Дж.К....  121026116
# 114   Гарри Поттер и философский камень /По роману Д...  121025916
# 122   Гарри Поттер и кубок огня /По роману Дж.К.Ролинг/  121026216
# ...                                                 ...        ...
# 6918                                          Дитя тьмы  121010819
# 7281                                           Прощание  121028719
# 7289                                       Игра с огнем  121029319
# 7322                                              Успех  111018519
# 7438                                              Зверь  121035919
#
#      show_start_date             type  \
# 110       2016-09-23   Художественный
# 111       2016-09-23   Художественный
# 113       2016-09-23   Художественный
# ...

# %%
data['puNumber'].duplicated().sum()
# Out:
# 2

# %% [markdown]
# Полностью повторяющих строк нет. Есть дубли в названиях фильмов, это связано с неоднократной выдачей прокатных удостоверений.

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Кажется, часть данных (неполные дубликаты — записи с одинаковыми фильмами и одинаковыми режиссерами) можно удалить, у которых отсутствуют значения в «денежных» колонках (бюджет, сборы и и т.д.)
#
#
# Такие фильмы могут повлиять на исследование в разделе 1.3
#
# ![image-2.png](attachment:image-2.png)

# %%
money_columns = ['refundable_support', 'nonrefundable_support', 'budget', 'box_office']

# Создаем маску для строк, где все денежные колонки пустые
empty_money_mask = data[money_columns].isnull().all(axis=1)

# Удаляем дубликаты по столбцам 'title' и 'director', оставляя только те строки, где денежные колонки не пустые
data = data[~(empty_money_mask & data.duplicated(subset=['title', 'director'], keep=False))]

data
# Out:
#                                              title   puNumber show_start_date  \
# 0                                 Открытый простор  221048915      2015-11-27
# 1                             Особо важное задание  111013716      2016-09-13
# 5                                Остановился поезд  111013816      2016-09-13
# 6                                  Любовь и голуби  111007013      2013-10-18
# 7                                Любовь и сигареты  221074614      2014-12-29
# ...                                            ...        ...             ...
# 7481     Сад художника: Американский импрессионизм  126008019      2019-12-23
# 7482                               Звериная ярость  121037819      2019-12-24
# 7483     Щенячий патруль: Скорей спешим на помощь!  124010819      2019-12-28
# 7484      Машины песенки. Серия "Испанские мотивы"  124010619      2019-12-30
# 7485  Машины песенки. Серия "Когда цветут кактусы"  124010719      2019-12-30
#
# ...

# %%
# check
data[data.duplicated(subset=['title', 'director'], keep=False)==True].sort_values('title')[['title', 
    'show_start_date','director', 'refundable_support', 'budget',
         'ratings', 'genres', 'box_office']]
# Out:
#                                                   title show_start_date  \
# 885                                          Арктика 3D      2012-10-18
# 887                                          Арктика 3D      2016-07-01
# 1209                                          Аэротачки      2014-10-07
# 1208                                          Аэротачки      2012-10-05
# 2610                                       Багровый пик      2015-07-23
# 2608                                       Багровый пик      2016-06-10
# 2633  Бегущий в лабиринте: Испытание огнем /По произ...      2015-07-31
# 2632  Бегущий в лабиринте: Испытание огнем /По произ...      2015-12-17
# 2177                                      Большая афера      2016-05-23
# 2178                                      Большая афера      2014-07-29
# 3052                                Виктор Франкенштейн      2015-11-12
# 3051                                Виктор Франкенштейн      2016-02-24
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит обработать и такие дубликаты ⬆⬆

# %% [markdown]
# #### Шаг 2.4. Изучите категориальные значения
#
# - Посмотрите, какая общая проблема встречается почти во всех категориальных столбцах;
# - Исправьте проблемные значения в поле `type`.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_1" aria-expanded="false" aria-controls="collapseHint_1">Подсказка</button>
#         </div>
#         <div id="collapseHint_1" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# В поле <code>type</code> есть несколько значений, у которых появился пробел в начале строки. Самый простой способ их «починить» -- использовать метод <a href="https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html#pandas.Series.str.strip">.str.strip</a>. Этот метод удаляет все пробелы, которые встречаются в начале и в конце строки. Применяют его таким образом:<br>
# <code>df['type'].str.strip()</code>
#             </div>
#         </div>
#     </div>
# </div>

# %%
data['type'] = data['type'].str.strip()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> От лишних пробелов избавились корректно, молодец

# %%
data['type'].value_counts()
# Out:
# Художественный                4982
# Анимационный                   775
# Прочие                         386
# Документальный                 280
# Научно-популярный               52
# Музыкально-развлекательный       1
# Name: type, dtype: int64

# %%
data['age_restriction'].unique()
# Out:
# array(['«18+» ', '«6+» ', '«12+» ', '«16+» ', '«0+» '], dtype=object)

# %%
data['financing_source'].unique()
# Out:
# array(['unknown', 'Министерство культуры', 'Фонд кино',
#        'Министерство культуры, Фонд кино'], dtype=object)

# %% [markdown]
# В столбце type были лишние пробелы, исправили это.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит исследовать содержимое всех текстовых колонок и определить основную проблему в колонках с категориальными данными
#
# (лишние пробелы это не проблема, она легко решается стандартными средствами)

# %%
# Определяем текстовые колонки
text_columns = data.select_dtypes(include=['object']).columns

# Исследуем уникальные значения в каждой текстовой колонке
for col in text_columns:
    print(f"Колонка: {col}")
    print(f"Количество уникальных значений: {data[col].nunique()}")
    print(f"Примеры уникальных значений: {data[col].unique()[:10]}")  # Выводим первые 10 уникальных значений
    print("-" * 50)
# Out:
# Колонка: title
# Количество уникальных значений: 6423
# Примеры уникальных значений: ['Открытый простор' 'Особо важное задание' 'Остановился поезд'
#  'Любовь и голуби' 'Любовь и сигареты' 'Отпетые мошенники.'
#  'Отпуск за свой счет'
#  'Превосходство Борна /По одноименной новелле Роберта Ладлэма/'
#  'Ответный ход' 'Преданный садовник']
# --------------------------------------------------
# Колонка: show_start_date
# Количество уникальных значений: 1889
# Примеры уникальных значений: [datetime.date(2015, 11, 27) datetime.date(2016, 9, 13)
#  datetime.date(2013, 10, 18) datetime.date(2014, 12, 29)
#  datetime.date(2016, 5, 5) datetime.date(2014, 12, 1)
#  datetime.date(2016, 6, 29) datetime.date(2013, 8, 26)
#  datetime.date(2012, 1, 27) datetime.date(2014, 12, 24)]
# --------------------------------------------------
# Колонка: type
# Количество уникальных значений: 6
# Примеры уникальных значений: ['Художественный' 'Анимационный' 'Прочие' 'Документальный'
# ...

# %%
data['film_studio'] = data['film_studio'].str.strip()
data['director'] = data['director'].str.strip()
data['title'] = data['title'].str.strip()

# %%
# Объединение дублирующихся категорий
data['film_studio'] = data['film_studio'].replace({
    'ООО "Мульт в кино" ': 'Мульт в Кино',
    'Эр А И Синема' : 'Р А И Синема'
})

# %%
# Проверяем частоту значений в категориальных колонках
for col in text_columns:
    print(f"Частота значений в колонке: {col}")
    print(data[col].value_counts().head(15))  # Выводим топ-10 значений
    print("-" * 50)
# Out:
# Частота значений в колонке: title
# Прощание                                                       4
# Успех                                                          3
# Супергерои                                                     2
# Лунный флаг                                                    2
# Волшебная страна.                                              2
# Пингвиненок Пороро: Большие гонки                              2
# Вторжение                                                      2
# Игра с огнем                                                   2
# Гарри Поттер и Дары Смерти - Часть 1/По роману Дж.К.Ролинг/    2
# Побег из Вегаса                                                2
# На колесах                                                     2
# Арктика 3D                                                     2
# Три сестры                                                     2
# Багровый пик                                                   2
# ...

# %%
#data.loc[data['director'].str.match('Стивен') == True]

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         'боевик,драма,мелодрама', 'драма,военный', 'фантастика,боевик,триллер', 'драма', 'мелодрама,комедия',
#
#         'Дэвид Валдес, Кевин Костнер, Джейк Эбертс', 'неизвестно', 'Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит'
#
#         'Дэниел Гродник Продакшнз, Вандерфилм Медиа Корпорэйшн, Импринт Интертейнмент, Вор Хорс Интертейнмент, Пимиента ', 'Никелодеон Анимейшн Студиос, Спин Мастер', 'Анимаккорд Лтд., ООО Студия "АНИМАККОРД"'
#
# Какая общая проблема связывает эти три отрывка данных

# %% [markdown]
# #### Шаг 2.5. Проверьте количественные значения
#
# - Проверьте, обнаружились ли в таких столбцах подозрительные данные. Как с такими данными лучше поступить?
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_budget" aria-expanded="false" aria-controls="collapseHint_budget">Подсказка</button>
#         </div>
#         <div id="collapseHint_budget" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Обратите внимание на описание столбца <code>budget</code>. Как этот столбец соотносится с двумя другими: <code>refundable_support</code> и <code>nonrefundable_support</code>?
#             </div>
#         </div>
#     </div>
# </div>

# %%
groups = ['refundable_support', 'nonrefundable_support',
          'budget', 'box_office']

# %%
data[groups].describe()
# Out:
#        refundable_support  nonrefundable_support        budget    box_office
# count        3.320000e+02           3.320000e+02  3.320000e+02  3.158000e+03
# mean         1.186446e+07           4.898099e+07  1.272297e+08  7.647870e+07
# std          2.491656e+07           5.998012e+07  1.885883e+08  2.403531e+08
# min          0.000000e+00           0.000000e+00  0.000000e+00  0.000000e+00
# 25%          0.000000e+00           2.500000e+07  4.200000e+07  8.623900e+04
# 50%          0.000000e+00           3.000000e+07  6.864992e+07  2.327988e+06
# 75%          1.500000e+07           4.037500e+07  1.419853e+08  2.397967e+07
# max          1.800000e+08           4.000000e+08  2.305074e+09  3.073569e+09

# %%
data[data['budget'] == 0].describe()
# Out:
#            puNumber  refundable_support  nonrefundable_support  budget  \
# count  1.700000e+01        1.700000e+01           1.700000e+01    17.0
# mean   1.120672e+08        1.670588e+07           6.517467e+07     0.0
# std    1.473501e+06        2.006478e+07           6.123620e+07     0.0
# min    1.110004e+08        0.000000e+00           0.000000e+00     0.0
# 25%    1.110096e+08        0.000000e+00           2.300000e+07     0.0
# 50%    1.110173e+08        1.000000e+07           5.100000e+07     0.0
# 75%    1.140017e+08        2.000000e+07           7.500000e+07     0.0
# max    1.140065e+08        6.000000e+07           2.500000e+08     0.0
#
#          box_office
# count  1.700000e+01
# mean   1.631373e+08
# std    2.511160e+08
# min    1.334699e+06
# 25%    5.045195e+07
# 50%    7.293778e+07
# 75%    1.844876e+08
# max    1.038321e+09

# %%
data[(data['refundable_support'] + data['nonrefundable_support']) > data['budget']]
# Out:
#                        title   puNumber show_start_date            type  \
# 2053                     14+  111023614      2014-12-19  Художественный
# 2058               Дуxless 2  111000415      2015-01-26  Художественный
# 2472             Воин (2015)  111017315      2015-09-28  Художественный
# 2532                 Бармен.  111009615      2015-05-26  Художественный
# 2615     Савва. Сердце воина  114001715      2015-07-21    Анимационный
# 2684          Тряпичный союз  111010215      2015-06-08  Художественный
# 2788      Срочно выйду замуж  111017115      2015-09-30  Художественный
# 2874       Помню - не помню!  111004916      2016-03-01  Художественный
# 3047  Любовь с ограничениями  111008216      2016-04-29  Художественный
# 3565       Притяжение (2016)  111018116      2016-12-16  Художественный
# 3675                Чудо-юдо  114001817      2017-06-27    Анимационный
# 3739                    Мифы  111004317      2017-06-07  Художественный
# ...

# %% [markdown]
# Видим, что есть фильмы с нулевым бюджетом, несмотря на то, что у этих фильмов нулевой бюджет, есть такие фильмы, где сумма поддержки ненулевая. В этом случае бюджет не может быть меньше суммы поддержки. Проверим кинокартины, у которых бюджет меньше суммы возвратных и невозвратных средств.

# %%
def correct_budget(row):
    if row['budget'] < (row['refundable_support'] + row['nonrefundable_support']):
        return row['refundable_support'] + row['nonrefundable_support']
    return row['budget']

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  У нас бюджет всегда больше чем просто сумма двух видов гос поддержки, стоит поправить алгоритм ⬆⬆

# %%
data['budget_corrected'] = data.apply(correct_budget, axis=1)

# %%
len(data[(data['refundable_support'] + data['nonrefundable_support']) > data['budget_corrected']])
# Out:
# 0

# %%
data['budget'] = data['budget_corrected']
del data['budget_corrected']

# %%
data[:].isna().sum()
# Out:
# title                       0
# puNumber                    0
# show_start_date             0
# type                        0
# film_studio                 0
# production_country          0
# director                    0
# producer                    0
# age_restriction             0
# refundable_support       6144
# nonrefundable_support    6144
# budget                   6144
# financing_source            0
# ratings                   953
# genres                      0
# box_office               3318
# dtype: int64

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит исследовать аномалии, выбросы и редкости в количественных данных более подробно
#
# например посмотреть на минимальные сборы фильмов, все ли корректно у нас в колонке `box_office`

# %%
# Общая статистика по колонке box_office
print(data['box_office'].describe())
# Out:
# count    3.158000e+03
# mean     7.647870e+07
# std      2.403531e+08
# min      0.000000e+00
# 25%      8.623900e+04
# 50%      2.327988e+06
# 75%      2.397967e+07
# max      3.073569e+09
# Name: box_office, dtype: float64

# %%
# Гистограмма для box_office
data['box_office'].hist(bins=50, edgecolor='black', figsize=(10, 6))
plt.title('Распределение сборов фильмов (box_office)')
plt.xlabel('Сборы')
plt.ylabel('Количество фильмов')
plt.show()

# %%
# Вычисляем квартильные значения
Q1 = data['box_office'].quantile(0.25)  # Первый квартиль (25%)
Q3 = data['box_office'].quantile(0.75)  # Третий квартиль (75%)
IQR = Q3 - Q1  # Интерквартильный размах

# Границы для выбросов
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Фильтруем выбросы
outliers = data[(data['box_office'] < lower_bound) | (data['box_office'] > upper_bound)]
print(f"Количество выбросов: {len(outliers)}")
outliers
# Out:
# Количество выбросов: 549
#                                                   title   puNumber  \
# 1869                              Женщины против мужчин  111002415
# 1870                             А зори здесь тихие..._  111002915
# 1897                                              Дом _  124000915
# 1898                               Робот по имени Чаппи  121003515
# 1899  Золушка /По сказке Шарля Перро/. Холодное торж...  121003615
# ...                                                 ...        ...
# 7435                                  Сиротский Бруклин  121036119
# 7453                            Фиксики против кработов  114004819
# 7456                                              Холоп  111021719
# 7464                                      Союз спасения  111022019
# 7466                        Иван Царевич и Серый Волк 4  114005019
#
#      show_start_date            type  \
# 1869      2015-03-12  Художественный
# 1870      2015-03-16  Художественный
# ...

# %%
# Фильмы с нулевыми сборами
zero_box_office = data[data['box_office'] == 0]
print(f"Количество фильмов с нулевыми сборами: {len(zero_box_office)}")
zero_box_office
# Out:
# Количество фильмов с нулевыми сборами: 24
#                                                   title   puNumber  \
# 66                                         Анна Павлова  111011013
# 237                                            Подранки  111007613
# 596                                       Запах вереска  111003012
# 914     В тумане /По одноименной повести Василя Быкова/  121027712
# 932                                     Письмо для Момо  124002912
# 933                                        Летние войны  124002812
# 976                                        Гарегин Нжде  131000213
# 1126                                            Марафон  111006712
# 1387  Экзамен для двоих /По роману Джин Ханфф Корелитц/  121014613
# 1559  Последняя любовь мистера Моргана /По роману Фр...  121002614
# 1772                                  Весёлые ребята ;)  111002414
# 1782                          Анжелика, маркиза ангелов  121031913
# ...

# %%
# Фильмы с очень низкими сборами (например, меньше 1000)
low_box_office = data[data['box_office'] < 1000]
print(f"Количество фильмов с очень низкими сборами: {len(low_box_office)}")
low_box_office
# Out:
# Количество фильмов с очень низкими сборами: 231
#                                          title   puNumber show_start_date  \
# 18                               Неподдающиеся  111003616      2016-02-12
# 19                                  Неподсуден  111003716      2016-02-12
# 22    Операция "Ы" и другие приключения Шурика  111007413      2013-10-18
# 61                           Американская дочь  111005515      2015-04-23
# 66                                Анна Павлова  111011013      2013-12-19
# ...                                        ...        ...             ...
# 5207               Ариэтти из страны лилипутов  124001211      2011-08-05
# 5241                   Другой мир: Пробуждение  121024511      2011-12-27
# 5297            Бой с тенью-3: последний раунд  111007211      2011-10-18
# 5343                      Хранитель времени 3D  121023411      2011-12-15
# 5388                                  ВОИН.com  111004411      2011-07-04
#
# ...

# %%
# Фильмы с очень высокими сборами (например, больше 1 миллиарда)
high_box_office = data[data['box_office'] > 1e9]
print(f"Количество фильмов с очень высокими сборами: {len(high_box_office)}")
high_box_office
# Out:
# Количество фильмов с очень высокими сборами: 55
#                                                   title   puNumber  \
# 1982                                        Седьмой сын  121026614
# 2105                                           Форсаж 7  121001215
# 2159                             Мстители: Эра Альтрона  121007215
# 2509                                Терминатор: Генезис  121012415
# 2511                             Монстры на каникулах 2  124003615
# 2578                                            Миньоны  124001715
# 2579                                Мир Юрского периода  121006515
# 2840                                             Дэдпул  121002116
# 2859                                         Зверополис  124000316
# 2920                                           Экипаж .  111005416
# 2938                              Книга джунглей (2016)  121006616
# 2991                                           Варкрафт  121011716
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отлично, молодец
#
# Возможно часть ошибок связана с форматом данных, кажется, таких ошибок особенно много до середины 2014 г. (пока прокатное удостоверение не стало обязательным)
#
#     5296	Бой с тенью-3: последний раунд	111007211	2011-10-18 12:00:00+00:00	Художественный	ООО "Шаман пикчерс"	Россия	А.Сидоров	Неизвестно	«16+» - для детей старше 16 лет	NaN	NaN	NaN	NaN	6.30	боевик,драма,криминал
#
#         сборы - 500.00
#
# Здесь скорее млн. руб., а не рубли
#
# Бой с тенью-3: последний раунд, сборы
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Шаг 2.6. Добавьте новые столбцы

# %% [markdown]
# - Создайте столбец с информацией о годе проката. Выделите год из даты премьеры фильма.

# %%
# Преобразуем колонку show_start_date в формат datetime
data['show_start_date'] = pd.to_datetime(data['show_start_date'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6476 entries, 0 to 7485
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  6476 non-null   object
#  1   puNumber               6476 non-null   int64
#  2   show_start_date        6476 non-null   datetime64[ns]
#  3   type                   6476 non-null   object
#  4   film_studio            6476 non-null   object
#  5   production_country     6476 non-null   object
#  6   director               6476 non-null   object
#  7   producer               6476 non-null   object
#  8   age_restriction        6476 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       6476 non-null   object
#  13  ratings                5523 non-null   object
# ...

# %%
data['show_start_year'] = data['show_start_date'].dt.year

# %% [markdown]
# - Создайте два столбца: с именем и фамилией главного режиссёра и основным жанром фильма. В столбцы войдут первые значения из списка режиссёров и жанров соответственно.
#
# <div id="accordion">
#     <div class="card">
#         <div class="card-header" id="headingThree">
#             <button class="btn btn-link collapsed" data-toggle="collapse" data-target="#collapseHint_2" aria-expanded="false" aria-controls="collapseHint_2">Подсказка</button>
#         </div>
#         <div id="collapseHint_2" class="collapse" aria-labelledby="headingThree" data-parent="#accordion">
#             <div class="card-body">
# Чтобы создать такие столбцы, лучше всего использовать собственную функцию. Эту функцию можно применить к двум столбцам сразу.
#             </div>
#         </div>
#     </div>
# </div>

# %%
data['director_first'] = data['director'].str.split(",").str[0]
data['genre_first'] = data['genres'].str.split(",").str[0]
data['director_first'] = data['director_first'].str.strip()
data['genre_first'] = data['genre_first'].str.strip()

# %%
data.head()
# Out:
#                   title   puNumber show_start_date            type  \
# 0      Открытый простор  221048915      2015-11-27  Художественный
# 1  Особо важное задание  111013716      2016-09-13  Художественный
# 5     Остановился поезд  111013816      2016-09-13  Художественный
# 6       Любовь и голуби  111007013      2013-10-18  Художественный
# 7     Любовь и сигареты  221074614      2014-12-29  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 5                              Киностудия "Мосфильм"               СССР
# 6                              Киностудия "Мосфильм"               СССР
# 7  Юнайтед Артистс, Грин Стрит Филмз, Айкон Интер...                США
#
#         director                                   producer age_restriction  \
# ...

# %% [markdown]
# - Посчитайте, какую долю от общего бюджета фильма составляет государственная поддержка.

# %%
data['ratio_help_to_budget'] = (data['refundable_support'] + data['nonrefundable_support']) / data['budget']

# %% [markdown]
# - Выделили год из даты премьеры и добавили в новый столбец;
# - Выделили первого в списке режиссера и жанр, также значения добавили в новые столбцы;
# - Посчитали долю государственной поддержки по отношению к бюджету.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Можно посмотреть на распределение данных о поддержке
#
# ![image-2.png](attachment:image-2.png)
#
# после твоих исправлений
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Шаг 3. Проведите исследовательский анализ данных

# %% [markdown]
# - Посмотрите, сколько фильмов выходило в прокат каждый год. Обратите внимание, что данные о прокате в кинотеатрах известны не для всех фильмов. Посчитайте, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах. Проанализируйте, как эта доля менялась по годам. Сделайте вывод о том, какой период полнее всего представлен в данных.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6476 entries, 0 to 7485
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  6476 non-null   object
#  1   puNumber               6476 non-null   int64
#  2   show_start_date        6476 non-null   datetime64[ns]
#  3   type                   6476 non-null   object
#  4   film_studio            6476 non-null   object
#  5   production_country     6476 non-null   object
#  6   director               6476 non-null   object
#  7   producer               6476 non-null   object
#  8   age_restriction        6476 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       6476 non-null   object
#  13  ratings                5523 non-null   object
# ...

# %%
df = data.loc[data.box_office.isna() == False].pivot_table(
    index='show_start_year', values='puNumber', aggfunc='count')
df
# Out:
#                  puNumber
# show_start_year
# 2010                  105
# 2011                  109
# 2012                  128
# 2013                  184
# 2014                  279
# 2015                  465
# 2016                  526
# 2017                  357
# 2018                  475
# 2019                  530

# %%
plt.plot(df.index, df)
plt.xlabel('Год')
plt.ylabel('Количество фильмов')
plt.title("График зависимости количества фильмов в прокате каждый год")
plt.show()

# %% [markdown]
# Резкое падение в 2017 году

# %% [markdown]
#  <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит корректно выполнить пункт проекта
#
#         Посмотрите, сколько фильмов выходило в прокат каждый год. Обратите внимание, что данные о прокате в кинотеатрах известны не для всех фильмов.
#
#         Посчитайте, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах. Проанализируйте, как эта доля менялась по годам. Сделайте вывод о том, какой период полнее всего представлен в данных.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Корректной оценке кол-ва фильмов, мешают почти 800 дублей в названиях фильмов

# %% [markdown]
# - Изучите, как менялась динамика проката по годам. В каком году сумма сборов была минимальной? А максимальной?

# %%
df = data.loc[data.box_office.isna() == False].pivot_table(
    index='show_start_year', values='box_office', aggfunc=['sum', 'mean', 'median'])
df = df / 1e6
df = df.round(3)  # Округляем до двух знаков после запятой
print('Примечание. Все значения указаны в миллионах')
df
# Out:
# Примечание. Все значения указаны в миллионах
#                        sum       mean     median
#                 box_office box_office box_office
# show_start_year
# 2010                 2.429      0.023      0.002
# 2011                14.103      0.129      0.003
# 2012                 6.955      0.054      0.006
# 2013                29.800      0.162      0.004
# 2014              7444.952     26.684      0.018
# 2015             39497.365     84.941      4.921
# 2016             47866.300     91.001      3.847
# 2017             48563.707    136.033      9.968
# 2018             49668.403    104.565      8.891
# 2019             48425.709     91.369      4.628

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит перевести формат чисел в удобный вид
#
#             2018	8891102.210	1.045651e+08
#             2019	4627798.345	9.136926e+07
#
# или разделить на млн., или на млрд., или добавить разделители (в моем примере числа не твои), копейки можно полностью отбросить, когда речь идет о миллиардах
#
#             2018	8_891_102	104_565_059
#             2019	4_627_798	91_369_261

# %%
fig, ax = plt.subplots(figsize=(15, 7))
ax.plot(df.index, df[('sum', 'box_office')], label='mean')

ax.set_ylabel('Сумма сборов')
ax.set_xlabel('Год')
ax.set_title("График зависимости суммы кассовых сборов фильмов в прокате каждый год")

None

# %% [markdown]
# - Минимальная выручка в 2010-2013 годах
# - Резкий рост выручки в 2014-2016 годах
# - Стагнацию выручки в 2018 - 2019 годах
# - Максимальная выручка была достигнута в 2019 году

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит отметить взрывной рост сборов в 2014 году, интересно с чем это может быть связано?

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Кажется, причина в этом
#
# ![image.png](attachment:image.png)
#
#
# </font>
# </font>
#
# <div>
# <font size="3", color = "red">
# <br />
#
# __и часть ошибок в колонке про сборы связана с форматом данных, кажется, таких ошибок особенно много до середины 2014 г. (пока прокатное удостоверение не стало обязательным)__

# %% [markdown]
# - С помощью сводной таблицы посчитайте среднюю и медианную сумму сборов для каждого года.

# %%
x = df.index
y1 = df[('mean', 'box_office')]
y2 = df[('median', 'box_office')]

fig, ax = plt.subplots(figsize=(15, 7))
ax.plot(x, y1, label='mean')
ax.plot(x, y2, label='median')
ax.set_ylabel('Выручка')
ax.set_xlabel('Год')
ax.set_title("Динамика изменения средних для каждого года")
ax.legend()
None

# %% [markdown]
# На графике мы видим резкий рост средней выручки с 2013 по 2017 год, но медиана практически неизменна, это значит что в года роста средней выручки были сверх успешные фильмы

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Отличное предположение о разнице, это важно — отметить в исследовании такие расхождения в статистиках

# %% [markdown]
# - Определите, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год? Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года? Если да, предположите, с чем это может быть связано.

# %%
df_pt = data.loc[
    (data.show_start_year > 2014) & (data.show_start_year < 2020)
    & (data.box_office.isna() == False)
].pivot_table(
    index=['age_restriction', 'show_start_year'],
    values=['box_office'],
    aggfunc=['sum', 'mean', 'median']
)
df_pt
# Out:
#                                           sum          mean        median
#                                    box_office    box_office    box_office
# age_restriction show_start_year
# «0+»            2015             3.790546e+08  9.719348e+06  2.943319e+06
#                 2016             1.502288e+08  3.664118e+06  2.571294e+06
#                 2017             2.295989e+08  7.653298e+07  2.217896e+07
#                 2018             3.244900e+07  6.489800e+06  3.616937e+06
#                 2019             1.774607e+07  5.915356e+06  3.885434e+06
# «12+»           2015             1.361608e+10  1.865217e+08  1.535156e+07
#                 2016             1.220445e+10  1.488347e+08  4.690635e+06
#                 2017             7.851428e+09  1.914982e+08  9.010548e+06
#                 2018             1.426729e+10  2.129447e+08  8.931966e+06
#                 2019             1.268020e+10  1.491788e+08  3.405546e+06
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Существует много способов изменить размерность чисел, начиная от простого деления в первоначальной выборке до выставления индивидуальных форматов для каждой колонки
#
# https://habr.com/ru/articles/521894/
#
#
# Важно другое — нельзя заказчику представлять подобные таблицы, которые невозможно исследовать без дополнительных затрат времени на расшифровку формата данных

# %%
x = range(2015, 2020)
fig, ax = plt.subplots(figsize=(20, 10))

for age in data.age_restriction.unique():
    y = []
    for year in x:
        y.append(df_pt.loc[df_pt.index == (age, year), ('sum', 'box_office')])
    ax.plot(x, y, label=age)

ax.set_ylabel('Выручка')
ax.set_xlabel('Год')
ax.set_title("Динамика изменения выручки от года в зависимости с возрастным ограничением")
ax.legend()
None

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Можно подправить подписи оси х, в виде целых 2015, 2016 ...,
#
# искать тему Ticks and ticklabels
#
# https://matplotlib.org/stable/tutorials/text/text_intro.html
#
# или
#
# https://dev-gang.ru/article/izmenenie-czastoty-tikov-v-matplotlib-k5x1kznn39/?ysclid=lcp5si8pky848462627

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️  Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит сократить названия для графика
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-5.png](attachment:image-5.png)

# %%
df_pt = data.loc[
    (data.show_start_year > 2014) & (data.show_start_year < 2020)
    & (data.box_office.isna() == False)
].pivot_table(
    index=['age_restriction'],
    values=['box_office'],
    aggfunc=['sum', 'mean', 'median']
)
df_pt
# Out:
#                           sum          mean       median
#                    box_office    box_office   box_office
# age_restriction
# «0+»             8.090774e+08  8.890961e+06   2943318.70
# «12+»            6.061945e+10  1.741938e+08   5065044.25
# «16+»            7.603473e+10  9.445309e+07   5600007.00
# «18+»            4.075962e+10  5.146416e+07   6154439.17
# «6+»             5.579861e+10  1.760209e+08  13736207.98

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(df_pt.index, df_pt[('sum', 'box_office')], label='mean')
plt.xticks(rotation=45)
ax.set_ylabel('Сумма сборов')
ax.set_xlabel('Возрастное ограничение')
ax.set_title("График зависимости суммы кассовых сборов фильмов от возрастного огранияения")

None

# %% [markdown]
# Фильмы 16+ в сумме имеют выручку больше всех

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит сортировать значения для графиков и развернуть график в горизонтальные бары, если надписи оси Х не умещаются в горизонтальном виде

# %% [markdown]
# ### Шаг 4. Исследуйте фильмы, которые получили государственную поддержку
#
# На этом этапе нет конкретных инструкций и заданий — поищите интересные закономерности в данных. Посмотрите, сколько выделяют средств на поддержку кино. Проверьте, хорошо ли окупаются такие фильмы, какой у них рейтинг.

# %%
df= data[data['budget'].isna() == False].copy()

# %%
df
# Out:
#                             title   puNumber show_start_date            type  \
# 1281                Пока еще жива  111005313      2013-10-11  Художественный
# 1448          Бесславные придурки  111003314      2014-03-28  Художественный
# 1498                    Невидимки  111004213      2013-09-10  Художественный
# 1524                        БЕРЦЫ  111004314      2014-05-05  Художественный
# 1792                     Братья Ч  111004414      2014-04-23  Художественный
# ...                           ...        ...             ...             ...
# 7464                Союз спасения  111022019      2019-12-26  Художественный
# 7466  Иван Царевич и Серый Волк 4  114005019      2019-12-20    Анимационный
# 7474                    Вторжение  111022519      2019-12-23  Художественный
# 7476                   Я свободен  111023019      2019-12-26  Художественный
# 7478        (Не)идеальный мужчина  111023119      2019-12-24  Художественный
#
# ...

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит проверить размерность новой выборки (сколько у нас данных и пропусков)
#
# Создали новую выборку — проверили целостность и полноту данных  🤝

# %%
# Проверяем размерность выборки
print(f"Размерность выборки: {df.shape}")

# Проверяем количество пропусков
missing_values = df.isna().sum()
print("Количество пропусков в каждом столбце:")
print(missing_values)

# Проверяем долю пропусков
missing_percentage = (df.isna().sum() / len(df)) * 100
print("Доля пропусков в каждом столбце (%):")
print(missing_percentage)

# Проверяем количество дубликатов
duplicates = df.duplicated().sum()
print(f"Количество дубликатов: {duplicates}")

# Общая информация о данных
print("Общая информация о данных:")
print(df.info())
# Out:
# Размерность выборки: (332, 20)
# Количество пропусков в каждом столбце:
# title                     0
# puNumber                  0
# show_start_date           0
# type                      0
# film_studio               0
# production_country        0
# director                  0
# producer                  0
# age_restriction           0
# refundable_support        0
# nonrefundable_support     0
# budget                    0
# financing_source          0
# ratings                  16
# genres                    0
# box_office               14
# show_start_year           0
# director_first            0
# genre_first               0
# ratio_help_to_budget      0
# dtype: int64
# Доля пропусков в каждом столбце (%):
# title                    0.000000
# puNumber                 0.000000
# show_start_date          0.000000
# type                     0.000000
# film_studio              0.000000
# production_country       0.000000
# director                 0.000000
# ...

# %%
df_gos = df.loc[
    (df.refundable_support != -1) | (df.nonrefundable_support != -1)
]
df_gos.production_country.value_counts()
# Out:
# Россия                                        316
# Россия, Германия                                2
# Россия, Италия                                  2
# Россия-Китай                                    1
# Россия - Грузия                                 1
# Россия, Армения                                 1
# Россия, Франция, Латвия                         1
# Россия-Словакия-Чехия                           1
# Россия, Украина, Польша                         1
# Россия, Германия, Великобритания                1
# Россия-Украина                                  1
# Россия, Сербия                                  1
# Россия, Латвия, Чешская Республика              1
# Россия, Бельгия, Финляндия                      1
# Россия, Германия, Казахстан, Польша, Китай      1
# Name: production_country, dtype: int64

# %%
df_gos['from_gos'] = df.refundable_support + df.nonrefundable_support
df_gos.from_gos = df_gos.from_gos.astype('float')
df_pt = df_gos.pivot_table(index='show_start_year', values=['budget', 'from_gos'], aggfunc='sum')
df_pt
# Out:
#                        budget      from_gos
# show_start_year
# 2013             2.554354e+08  1.343479e+08
# 2014             1.302485e+09  5.720023e+08
# 2015             7.738669e+09  3.656241e+09
# 2016             7.554943e+09  4.303155e+09
# 2017             7.057173e+09  3.183972e+09
# 2018             7.000664e+09  3.446969e+09
# 2019             1.272287e+10  4.904000e+09

# %% [markdown]
# Динамика изменения финансовых показателей фильмов по годам
#
# - budget - общий бюджет фильма
# - from_gos - объём государственной поддержки

# %%
df_pt.plot(title='Динамика изменения финансовых показателей фильмов по годам')
plt.xlabel('Год')  # Подпись оси X
plt.ylabel('Финансовые показатели (млн)')  # Подпись оси Y

# Отображаем график
plt.show()

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит полностью оформить все графики на проекте
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)
#
# Все надписи для графиков стоит оформлять на языке выполнения проекта

# %% [markdown]
# - Рост бюджета по годам: резкие скачки наблюдаются в 2014-2015 и 2018-2019 годах, стагнация в 2015-2018 годах
# - Рост объёма финансирования по годам: резкие скачки наблюдаются в 2014-2015 и 2018-2019 годах, стагнация в 2017-2018 годах, уменьшение финансирования наблюдается в 2016-2017 годах

# %%
df_pt = df_gos.pivot_table(index='show_start_year', values=['budget', 'from_gos', 'box_office'], aggfunc=['mean', 'median'])
df_pt
# Out:
#                          mean                                   median  \
#                    box_office        budget      from_gos   box_office
# show_start_year
# 2013             1.016119e+07  1.277177e+08  6.717397e+07  10161192.55
# 2014             6.358889e+07  8.140530e+07  3.575014e+07   5504517.85
# 2015             6.806218e+07  8.998453e+07  4.251444e+07   9200824.50
# 2016             1.013618e+08  1.238515e+08  7.054353e+07  17921115.61
# 2017             2.785917e+08  1.721262e+08  7.765785e+07  50451949.00
# 2018             1.773941e+08  1.250119e+08  6.155303e+07  27023390.31
# 2019             1.401605e+08  1.817552e+08  7.005714e+07  25977291.30
#
#
#                       budget    from_gos
# show_start_year
# 2013             127717695.0  67173972.5
# 2014              61036441.5  27500000.0
# 2015              57493985.5  30000000.0
# 2016              69883049.0  35000000.0
# 2017              78096315.0  40000000.0
# ...

# %%
df_pt.plot(title='Динамика изменения средних финансовых показателей фильмов по годам')
None

# %%
x = df_gos.loc[df_gos.show_start_year == 2016, 'box_office']
y = df_gos.loc[df_gos.show_start_year == 2017, 'box_office']



pyplot.hist(x, alpha=0.5, label='2016')
pyplot.hist(y, alpha=0.5, label='2017')
pyplot.legend(loc='upper right')
pyplot.show()

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Импорт библиотек стоит выносить на первые строки проекта, так коллегам будет удобнее настроить свои рабочие места под наши требования

# %% [markdown]
# По распределению Пуассона, в 2016 году больше "дешевых" фильмов, а в 2017 году мы выдим "дорогие" фильмы

# %% [markdown]
# Посчитаем ROS - рентабельность (гос инвестиций) для фильмов с гос. поддержкой

# %%
df_gos['ros'] = df_gos.box_office / (df_gos.refundable_support + df_gos.nonrefundable_support)
df_gos.ros.mean()
# Out:
# 1.8776010211541323

# %%
df_gos.ros.median()
# Out:
# 0.4396113897

# %%
df_gos.ros.std(ddof=0)
# Out:
# 4.310316481964723

# %% [markdown]
# ROS.mean() = 88% ROS.median() = -44% ROS.std() = 4.31

# %% [markdown]
# Сгруппируем фильмы по годам, и посмотрим средний (медианный) ROS для каждого года

# %%
df_pt = df_gos.pivot_table(index='show_start_year', values='ros', aggfunc=['mean', 'median'])
df_pt
# Out:
#                      mean    median
#                       ros       ros
# show_start_year
# 2013             0.099417  0.099417
# 2014             1.563709  0.162975
# 2015             1.354060  0.183483
# 2016             1.278799  0.324244
# 2017             3.062531  1.310201
# 2018             2.370559  0.784440
# 2019             2.130765  0.468695

# %%
df_pt.plot(title='Динамика изменения, среднего (медианного) ROS по годам')
None

# %% [markdown]
# Мы видим тенденцию роста рентабельности кинофильмов, с 2013 по 2017 года, максимум был достугнут в 2017, затем наблюдается спад

# %%
df_gos.loc[df.show_start_year == 2017].sort_values(by='box_office', ascending=False).head(5)
# Out:
#                                 title   puNumber show_start_date  \
# 5653                   Движение вверх  111011817      2017-12-21
# 5505               Последний богатырь  111007017      2017-10-19
# 5641                       Ёлки Новые  111011617      2017-12-21
# 5659  Три богатыря и принцесса Египта  114003317      2017-12-21
# 5502                          Салют-7  111006917      2017-10-01
#
#                 type                                        film_studio  \
# 5653  Художественный              ООО "Студия "ТРИТЭ" Никиты Михалкова"
# 5505  Художественный  ООО "Киностудия "Слово" по заказу ООО "Уолт Ди...
# 5641  Художественный                                       ООО "ТаББаК"
# 5659    Анимационный          ООО "Студия анимационного кино "Мельница"
# 5502  Художественный                           ООО "Лемон Филмз Студио"
#
#      production_country                                           director  \
# ...

# %% [markdown]
# Исследуем зависимости в данных

# %%
pd.plotting.scatter_matrix(df_gos, figsize=(80, 80), alpha=1)
None

# %%
corr_matrix = df_gos.corr()
corr_matrix
# Out:
#                        puNumber  refundable_support  nonrefundable_support  \
# puNumber               1.000000            0.010413              -0.030194
# refundable_support     0.010413            1.000000               0.359622
# nonrefundable_support -0.030194            0.359622               1.000000
# budget                -0.016573            0.654865               0.621026
# box_office             0.053665            0.312137               0.455729
# show_start_year       -0.017975            0.089616               0.117645
# ratio_help_to_budget   0.010212            0.003491               0.132406
# from_gos              -0.021326            0.638945               0.947567
# ros                    0.062380            0.119388               0.022759
#
#                          budget  box_office  show_start_year  \
# puNumber              -0.016573    0.053665        -0.017975
# refundable_support     0.654865    0.312137         0.089616
# ...

# %% [markdown]
# Тепловая карта

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(15, 15)})
sns.heatmap(corr_matrix, annot=True)
None

# %% [markdown]
# Можем сделать вывод, что
#
# - Бюджет более чем на половину зависит от государственных инвестиций
# - Рентабельность зависит от выручки (ROS введенная мной метрика)
# - Выручка зависит от объема гос инвестиций

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит отметить ТОП-10 успешных режиссеров, которые получили и гос поддержку, и обеспечили огромные суммы сборов, чтобы ответить на доп. вопрос — "Кому выдавать деньги в следующем году?"

# %%
# Фильтруем данные: только фильмы с гос. поддержкой и ненулевыми сборами
filtered_df = df_gos.loc[
    (df_gos['refundable_support'] + df_gos['nonrefundable_support'] > 0) & 
    (df_gos['box_office'].notna() & df_gos['box_office'] > 0)
]
#filtered_df

# %%
# Считаем общую поддержку, сборы и средний ROS по режиссерам
directors_stats = filtered_df.groupby('director_first').agg(
    total_support=('refundable_support', 'sum'),  # Сумма возвратной поддержки
    total_nonrefundable_support=('nonrefundable_support', 'sum'),  # Сумма невозвратной поддержки
    total_box_office=('box_office', 'sum'),  # Сумма сборов
    avg_ros=('ros', 'mean')  # Средний ROS
).reset_index()
# Считаем общую поддержку (возвратная + невозвратная)
directors_stats['total_support'] = (
    directors_stats['total_support'].fillna(0) + 
    directors_stats['total_nonrefundable_support'].fillna(0)
)

# %%
# Убираем ненужные колонки
directors_stats = directors_stats[['director_first', 'total_support', 'total_box_office', 'avg_ros']]
top_directors = directors_stats.sort_values(by='total_box_office', ascending=False).head(10)

# Преобразуем числа для удобства (например, делим на миллионы)
top_directors['total_support'] = (top_directors['total_support'] / 1e6).round(2)
top_directors['total_box_office'] = (top_directors['total_box_office'] / 1e6).round(2)
top_directors['avg_ros'] = top_directors['avg_ros'].round(2)

# %%
top_directors.rename(columns={
    'total_support': 'Гос. поддержка (млн)',
    'total_box_office': 'Сборы (млн)',
    'avg_ros': 'Средний ROS'
}, inplace=True)
top_directors
# Out:
#     director_first  Гос. поддержка (млн)  Сборы (млн)  Средний ROS
# 154      К.Шипенко                 312.0      3827.77        18.21
# 37    А.Мегердичев                 400.0      2779.69         6.95
# 93      Д.Дьяченко                 351.0      2404.90         6.68
# 52       А.Сидоров                 180.0      2271.75        12.62
# 194       О.Трофим                  85.0      1445.73        17.01
# 104        Д.Шмидт                 215.0      1412.48         8.46
# 178      Н.Лебедев                 442.1      1402.26         3.17
# 95       Д.Киселев                 350.0      1399.78         5.37
# 238    Ф.Бондарчук                 250.0      1038.32         4.15
# 228  Т.Бекмамбетов                 250.0      1009.91         4.54

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Стоит посмотреть и на антилидеров, которые принесли суперубытки — ТОП-10__

# %%
loss_directors = directors_stats.sort_values(by='total_box_office', ascending=True).head(10)
loss_directors['total_support'] = (loss_directors['total_support'] / 1e6).round(2)
loss_directors['total_box_office'] = (loss_directors['total_box_office'] / 1e6).round(2)
loss_directors['avg_ros'] = loss_directors['avg_ros'].round(2)
loss_directors.rename(columns={
    'total_support': 'Гос. поддержка (млн)',
    'total_box_office': 'Сборы (млн)',
    'avg_ros': 'Средний ROS'
}, inplace=True)
loss_directors
# Out:
#                            director_first  Гос. поддержка (млн)  Сборы (млн)  \
# 176                          Н.Джорджадзе                  26.5         0.00
# 124                            И.Кордзаия                  25.9         0.01
# 150                           К.Сухарьков                  25.0         0.02
# 140                            К.Геворкян                  30.0         0.04
# 113                             Е.Татаров                  26.0         0.04
# 237                             Ф.Абрютин                  30.0         0.04
# 35                              А.Майовер                  35.0         0.05
# 102                             Д.Федоров                  34.0         0.05
# 81                            В.Сторожева                  23.5         0.06
# 111  Е.Миндадзе (псевдоним Катя Шагалова)                  28.0         0.06
#
#      Средний ROS
# 176          0.0
# 124          0.0
# 150          0.0
# 140          0.0
# 113          0.0
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Кажется, список антилидеров чуть-чуть другой, потратили огромное кол-во денег и провалились в прокате ⬇⬇

# %%
# check
mkrf_movies = data.copy()
mkrf_movies['pro'] = mkrf_movies['box_office'] - mkrf_movies['budget']
# у меня упрощенный расчет, без учета невозврата ⬆⬆

mkrf_movies[mkrf_movies['box_office'] > 0].sort_values('pro', ascending=True)[['title', 
    'show_start_date','director', 'refundable_support', 'nonrefundable_support', 'budget', 'box_office', 'pro']][:10
        ].style.format({'pro':"{:_.0f}"})
# и без оформления миллиардов в красивый и удобный вид 🤝, частично поправил вид последней колонки
# Out:
# <style  type="text/css" >
# </style><table id="T_2f99a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >title</th>        <th class="col_heading level0 col1" >show_start_date</th>        <th class="col_heading level0 col2" >director</th>        <th class="col_heading level0 col3" >refundable_support</th>        <th class="col_heading level0 col4" >nonrefundable_support</th>        <th class="col_heading level0 col5" >budget</th>        <th class="col_heading level0 col6" >box_office</th>        <th class="col_heading level0 col7" >pro</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2f99a_level0_row0" class="row_heading level0 row0" >7114</th>
#                         <td id="T_2f99a_row0_col0" class="data row0 col0" >Тайна Печати Дракона</td>
#                         <td id="T_2f99a_row0_col1" class="data row0 col1" >2019-09-12 00:00:00</td>
# ...

# %% [markdown]
# ### Шаг 5. Напишите общий вывод

# %% [markdown]
# Данные содержать много ошибок, среди них:
# - Лишние пробелы в категориальных переменных - исправлено;
# - Рейтинги в процентах для некоторых строк - такие значения приведены к NaN;
# - В датасете есть дубликаты по названию фильма, но у этих кинокартин разные номера прокатных удостоверений, поэтому оставили данные без доп. обработки;
# - Также есть фильмы с одинаковыми номерами прокатных удостоверений, но, проверив, такие фильмы на официальном - подтвердили, что все так и есть. Видимо, под одним номером может быть в прокате несколько фильмов.
# - В бюджете фильмов были нулевые значения. В таких строках нулевой бюджет заменили на сумму поддержки.
# - Для анализа добавили дополнительные столбцы с годом старта показа картины, первого в списке режиссера, и первого в списке жанра, а также отношение суммы поддержки к бюджету.
# - Больше всего фильмов было показано в кинотеатре в 2019 году, чуть меньше - в 2016. Минимальная сумма сборов была в 2015, максимальная в 2018.
# - Наибольшая "средняя" сумма сборов приходится на 2017 год. Больше всего сборов у фильмов 16+. Если смотреть по годам, то в 2017 году кино 16+ принесло больше всех денег, но в 2015 более "кассовое" кино было 12+.
# - Больше всего было денег выделено гос. фондом в 2019 году, чуть меньше - в 2016. Но в среднем по медиане самый большой бюджет на каждый фильм приходится на 2018 год. Самые худшие (по рейтингу) фильмы были в прокате в 2016 году. В остальные годы средняя оценка была около 6 баллов. На рейтинг фильма увеличение суммы поддержки особо не влияет.

# %% [markdown]
# - Сумма Гос поддержки фильмов увеличивается с каждым годом
# - ROS = 88%, фильмы окупаются практически в 2 раза
# - На гистограмме столбца show_start_date — дата премьеры фильма, мы видим резкое увеличение числа фильмов с 2014 по 2016 года, что соответствует увеличению финансирования кино индустрии в эти года, но как мы помним роста в среднем рейтинге в эти года не было.
# - Бюджет более чем на половину зависит от государственных инвестиций
# - Рентабельность зависит от выручки (ROS)
# - Выручка зависит от объема гос инвестиций
# - Резкий рост средней выручки с 2013 по 2017 год, но медиана практически неизменна, это значит что в года роста средней выручки были сверх успешные фильмы

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Стоит добавить новых инсайтов в итоговый вывод

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит перепроверить результаты и итоговый вывод после   исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Ты выполнил практически все пункты проекта, молодец! Проведен значительный объем исследования
#
#
# Критические ❌ комментарии:
#
#  + добавить вступление
#  + проверить размерность всех новых таблиц
#  + отменить удаление части выборки
#  + поправить удаление дубликатов
#  + объяснить какая основная проблема категориальных данных
#  + выполнить поиск аномалий в количественных данных
#  + определить успешных режиссеров на гос поддержке
#  + прочие
#  + перепроверить промежуточные и итоговый выводы после всех исправлений
#
#
#
#
# Стоит обратить внимание на ⚠️ комментарии...
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />    Может пригодиться
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#
#
# [8 способов фильтрации фреймов данных Pandas](https://questu.ru/articles/85248/)
#
# [Визуализация](https://dfedorov.spb.ru/pandas/%D0%AD%D1%84%D1%84%D0%B5%D0%BA%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5%20%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20Matplotlib.html)
#
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Если добавить запятую или знак нижнего подчеркивания, будет удобнее смотреть на большие числа
#
#         pd.options.display.float_format = '{:,.2f}'.format
#
#         pd.options.display.float_format = '{:_.2f}'.format

# %% [markdown]
# ## Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Можно разбить все списки при помощи кода explode (разбиение)
#
# <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.explode.html" rel="noreferrer noopener" target="_blank">explode</a>
#
# Для чего она нужна? Функция explode полезна в тех случаях, когда записи столбца похожи на список: она позволяет создавать новую строку для каждой записи в этих списках. При этом все остальные записи строки будут продублированы, как и индекс. Вызывая эту функцию, вы передаете имя столбца, содержащего спископодобные объекты
#
#     При ее использовании размер датафрейма может увеличиться. Предположим, у вас есть датафрейм с 500 000 строками и столбец, в котором хранятся списки из 100 записей. Вызвав функцию explode для этого столбца, вы в итоге получите 50 000 000 строк. Это может стать проблемой. Поэтому мой совет таков: используйте explode с осторожностью!
#
# [Четыре метода, которые повысят качество работы с Pandas](https://nuancesprog.ru/p/15496/?ysclid=lqwok44vr9838974329)
#
# стоит обратить внимание на первый и на четвертый

# %%
# import pandas as pd
n_rows = 3
result = pd.DataFrame(
    {"a": [list(range(1 + i ** 2)) for i in range(n_rows)], "b": list(range(n_rows))}
)

# %%
result
# Out:
#                  a  b
# 0              [0]  0
# 1           [0, 1]  1
# 2  [0, 1, 2, 3, 4]  2

# %%
result.loc[3]=([4, 2, 1, 4, 3], 2)
result
# Out:
#                  a  b
# 0              [0]  0
# 1           [0, 1]  1
# 2  [0, 1, 2, 3, 4]  2
# 3  [4, 2, 1, 4, 3]  2

# %%
result = result.explode("a").astype({'a':int})
result
# Out:
#    a  b
# 0  0  0
# 1  0  1
# 1  1  1
# 2  0  2
# 2  1  2
# 2  2  2
# 2  3  2
# 2  4  2
# 3  4  2
# 3  2  2
# 3  1  2
# 3  4  2
# 3  3  2

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       13 non-null     int64
#  1   b       13 non-null     int64
# dtypes: int64(2)
# memory usage: 312.0 bytes

# %%
result.duplicated().sum()
# Out:
# 5

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# Стоит попросить наставника провести вебинар на тему: «Автоматизация работы по исключению основных ошибок в текстовых данных»
#
# способы работы с регулярными выражениями
#
# статья масштабная, но если тема интересует, то пригодится
#
# [Регулярные выражения в Python ](https://habr.com/ru/post/349860/?ysclid=l7al1yi73m163595855)
#
# [Примеры использования регулярных выражений в поиске](https://kanoki.org/2019/11/12/how-to-use-regex-in-pandas/)
